# %%
True and True
# Out:
# True

# %%
True and False
# Out:
# False

# %%
False and False
# Out:
# False

# %%
False or False
# Out:
# False

# %%
False or True
# Out:
# True

# %%
True or True
# Out:
# True

# %%
not True
# Out:
# False

# %%
not False
# Out:
# True

# %%
3 < 5 and 100 >= 150
# Out:
# False

# %%
3 < 5 or 100 >= 150
# Out:
# True

# %%
True and not True
# Out:
# False

# %%
False or not True and False
# Out:
# False

# %%
True and not True or True
# Out:
# True

# %%
5 is 6
# Out:
# False

# %%
5 is not 6
# Out:
# True

# %%
5 == 6
# Out:
# False

# %%
5 != 6
# Out:
# True

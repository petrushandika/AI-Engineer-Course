# %%
# Strings
# Text values composed of a sequence of characters

# %%
'Petrus'
# Out:
# 'Petrus'

# %%
"Petrus"
# Out:
# 'Petrus'

# %%
print('Petrus')
# Out:
# Petrus

# %%
print("Petrus")
# Out:
# Petrus

# %%
x4 = 'Petrus'
x4
# Out:
# 'Petrus'

# %%
# Python can automatically guess the type of data you are entering

# %%
# Incorrect
# y = 10
# print(y + " Dollars")
# Its will be make the code error

# %%
# Correct
y = 10
print(str(y) + " Dollars")
# Out:
# 10 Dollars

# %%
"I'm Fine"
# Out:
# "I'm Fine"

# %%
'I\'m fine'
# Out:
# "I'm fine"

# %%
"Red " "Car"
# Out:
# 'Red Car'

# %%
print("Red " "Car")
# Out:
# Red Car

# %%
print("Red " + "Car")
# Out:
# Red Car

# %%
print("Red", "Car")
# Out:
# Red Car

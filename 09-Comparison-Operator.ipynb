# %%
10 == 10
# Out:
# True

# %%
10 != 10
# Out:
# False

# %%
10 != 15
# Out:
# True

# %%
100 < 50
# Out:
# False

# %%
100 > 50
# Out:
# True

# %%
15 >= 10 + 10
# Out:
# False

# %%
15 >= 10 + 5
# Out:
# True

# %%
# Operand
5 + 3
# Out:
# 8

# %%
8 - 1
# Out:
# 7

# %%
# Division

# %%
16 / 3
# Out:
# 5.333333333333333

# %%
# What a different in python 2 with python 3?
# 16 / 3 = 5 in Python 2 and 16 / 3 = 5.333... in Python 3

# %%
float(16) / 3
# Out:
# 5.333333333333333

# %%
16.0 / 3
# Out:
# 5.333333333333333

# %%
# Modulos

# %%
16 % 3
# Out:
# 1

# %%
# Multiplication

# %%
5 * 3
# Out:
# 15

# %%
x = 5 * 3
x
# Out:
# 15

# %%
# Double star operator

# %%
5 ** 3
# Out:
# 125

# %%
f

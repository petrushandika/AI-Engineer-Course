# %%
# Integers
# Positive or negative whole numbers, without a decimal point

# %%
x1 = 5
type(x1)
# Out:
# int

# %%
type(-6)
# Out:
# int

# %%
x2 = 4.6
type(x2)
# Out:
# float

# %%
float(5)
# Out:
# 5.0

# %%
# Boolean values
# A "True" or "False" value like 1 or 0, and on or off

# %%
x3 = True
type(x3)
# Out:
# bool
